# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/chrisbuetti/Desktop/calm3.xlsx', index_col=None)

# %%
df.head()
# Out:
#            pk                   username                       link  \
# 0  6866425401           studio_e_houston           studio_e_houston
# 1  1386910527             iamiulianiancu             iamiulianiancu
# 2  6524659654  empoweredmindbodywellness  empoweredmindbodywellness
# 3  5523248566                   mal_made                   mal_made
# 4  1539984310               talulah_hess               talulah_hess
#
#                    full_name  is_verified  media_count  follower_count  \
# 0             Erica Sandberg        False          609             540
# 1               Iulian Iancu        False          856            4720
# 2  Empower Pilates Mind Body        False           98             310
# 3             M A L  M A D E        False          770           52751
# 4             Talulah & HESS        False         1383            6532
#
#    following_count  following_tag_count  \
# 0             1292                    0
# 1             1283                    0
# ...

# %% [markdown]
# Create a column that is email prefix. ie: talulahandhess@gmail.com	 to just say talulahandhess

# %%
"talulahandhess@gmail.com".split("@")
# Out:
# ['talulahandhess', 'gmail.com']

# %% [markdown]
# Create a column "is gmail"

# %%
"gmail" in "talulahandhess@gmail.com"
# Out:
# True
